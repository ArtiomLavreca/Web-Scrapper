# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
from time import sleep
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By

# %%
import csv
import pandas as pd

# %%
service = Service(executable_path='chromedriver.exe')
browser = webdriver.Chrome(service=service)
url = 'https://999.md/ro/list/real-estate/apartments-and-rooms?view_type=short&appl=1&ef=16,6,2307,2200&eo=13859,12885,12900,12912&o_16_1=776&o_32_8_12900=13859'
browser.get(url)

# %%
block = browser.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div/div[2]')
ads = block.find_elements(By.CLASS_NAME,'AdShort_wrapper__S8kqq')
print(len(ads))
print(ads)
# Out:
# 84
# [<selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.375")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.376")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.377")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.378")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.379")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.380")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.381")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.382")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.383")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.384")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.385")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.386")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.387")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.388")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.389")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.390")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.391")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.392")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.393")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.394")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2BAFA41ED1DD261A16.e.395")>, <selenium.webdriver.remote.webelement.WebElement (session="7e05eebfcc53e2bc37db1158ac09f0eb", element="f.459FADE8684D614C87D25CB2D5CC526E.d.0195B0C09BEFBE2B ...

# %%
ads[1].text.splitlines()
# Out:
# ['Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.',
#  'm2',
#  '105 000 €',
#  '18 iul. 2025, 14:51']

# %%
for ad in ads:
    print(ad.text)
# Out:
# Apartament cu 1 cameră, Centru, Chișinău, Chișinău mun.
# m2
# 37 900 €
# 18 iul. 2025, 14:51
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 105 000 €
# 18 iul. 2025, 14:51
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 81 500 €
# 18 iul. 2025, 14:51
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 135 900 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Telecentru, Chișinău, Chișinău mun.
# m2
# 80 900 €
# 18 iul. 2025, 14:50
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 64 400 €
# 18 iul. 2025, 14:50
# Apartament cu 4 camere, Durlești, Chișinău, Chișinău mun.
# m2
# 119 900 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 165 000 €
# 18 iul. 2025, 14:50
# Apartament cu 3 camere, 95 m², Centru, Chișinău
# m2
# 289 000 €
# 18 iul. 2025, 14:50
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 100 000 €
# Apartament cu 3 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 220 000 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# m2
# 250 000 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 75 900 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 117 500 €
# 18 iul. 2025, 14:50
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 55 000 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 91 000 €
# 18 iul. 2025, 14:50
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 77 500 €
# 18 iul. 2025, 14:50
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 249 900 €
# 18 iul. 2025, 14:50
# Apartament cu 3 camere, Ciocana, Chișinău, Chișinău mun.
# m2
# 154 900 €
# 18 iul. 2025, 14:50
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 144 900 €
# 18 iul. 2025, 14:49
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# m2
# 165 000 €
# 18 iul. 2025, 14:48
# Apartament cu 3 camere, Durlești, Chișinău, Chișinău mun.
# m2
# 110 000 €
# 18 iul. 2025, 14:48
# Apartament cu 2 camere, Ciocana, Chișinău, Chișinău mun.
# m2
# 98 000 €
# Apartament cu 3 camere, Telecentru, Chișinău, Chișinău mun.
# m2
# 139 900 €
# 18 iul. 2025, 14:48
# Apartament cu 1 cameră, Buiucani, Chișinău, Chișinău mun.
# m2
# 95 000 €
# 18 iul. 2025, 14:47
# Apartament cu 1 cameră, Buiucani, Chișinău, Chișinău mun.
# m2
# 89 999 €
# 18 iul. 2025, 14:47
# Apartament cu 2 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 185 000 €
# 18 iul. 2025, 14:45
# Apartament cu 3 camere, Centru, Chișinău mun.
# 107 000 €
# 18 iul. 2025, 14:45
# Apartament cu 3 camere, Durlești, Chișinău, Chișinău mun.
# m2
# 122 000 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 101 250 €
# 18 iul. 2025, 14:45
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 120 000 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Telecentru, Chișinău, Chișinău mun.
# m2
# 53 300 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 93 500 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# m2
# 127 500 €
# 18 iul. 2025, 14:45
# Apartament cu 3 camere, Centru, Chișinău, Chișinău mun.
# 950 €
# Apartament cu 1 cameră, Buiucani, Chișinău, Chișinău mun.
# m2
# 94 900 €
# 18 iul. 2025, 14:45
# O cameră, Ciocana, Chișinău, Chișinău mun.
# m2
# 30 500 €
# 18 iul. 2025, 14:45
# Apartament cu 1 cameră, Botanica, Chișinău, Chișinău mun.
# m2
# 99 900 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 69 900 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 72 000 €
# 18 iul. 2025, 14:45
# Apartament cu 3 camere, Ciocana, Chișinău, Chișinău mun.
# m2
# 234 900 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 157 000 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Durlești, Chișinău, Chișinău mun.
# m2
# 111 500 €
# 18 iul. 2025, 14:45
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 209 900 €
# 18 iul. 2025, 14:45
# Apartament cu 1 cameră, Durlești, Chișinău, Chișinău mun.
# m2
# 117 900 €
# 18 iul. 2025, 14:44
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 150 000 €
# 18 iul. 2025, 14:44
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# m2
# 122 900 €
# 18 iul. 2025, 14:44
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 255 000 €
# Apartament cu 2 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 168 000 €
# 18 iul. 2025, 14:44
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 75 000 €
# 18 iul. 2025, 14:42
# Apartament cu 1 cameră, Buiucani, Chișinău, Chișinău mun.
# m2
# 98 000 €
# 18 iul. 2025, 14:42
# Apartament cu 2 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 109 000 €
# 18 iul. 2025, 14:42
# Apartament cu 1 cameră, Ciocana, Chișinău, Chișinău mun.
# m2
# 67 500 €
# 18 iul. 2025, 14:40
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 73 000 €
# 18 iul. 2025, 14:40
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 125 900 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Ciocana, Chișinău, Chișinău mun.
# m2
# 159 900 €
# 18 iul. 2025, 14:40
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 169 900 €
# 18 iul. 2025, 14:40
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 195 000 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# 50 €
# Apartament cu 1 cameră, Ciocana, Chișinău, Chișinău mun.
# m2
# 117 900 €
# 18 iul. 2025, 14:40
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 76 000 €
# 18 iul. 2025, 14:40
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 74 500 €
# 18 iul. 2025, 14:40
# Apartament cu 1 cameră, Centru, Chișinău, Chișinău mun.
# m2
# 63 000 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 106 500 €
# 18 iul. 2025, 14:40
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 119 000 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 109 000 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# m2
# 179 000 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Centru, Chișinău mun.
# m2
# 133 000 €
# 18 iul. 2025, 14:40
# Apartament cu 1 cameră, Durlești, Chișinău, Chișinău mun.
# m2
# 77 000 €
# 18 iul. 2025, 14:40
# Apartament cu 5 camere sau mai multe, Botanica, Chișinău, Chișinău mun.
# 6 000 €
# Apartament cu 2 camere, Ciocana, Chișinău, Chișinău mun.
# m2
# 149 900 €
# 18 iul. 2025, 14:40
# Apartament cu 2 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 110 000 €
# 18 iul. 2025, 14:39
# Apartament cu 1 cameră, Telecentru, Chișinău, Chișinău mun.
# m2
# 100 500 €
# 18 iul. 2025, 14:39
# Apartament cu 2 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 89 900 €
# 18 iul. 2025, 14:39
# Apartament cu 1 cameră, Centru, Chișinău mun.
# m2
# 125 000 €
# 18 iul. 2025, 14:39
# Apartament cu 3 camere, Botanica, Chișinău, Chișinău mun.
# m2
# 244 900 €
# 18 iul. 2025, 14:39
# Apartament cu 2 camere, Buiucani, Chișinău, Chișinău mun.
# m2
# 69 900 €
# 18 iul. 2025, 14:38
# Apartament cu 3 camere, Buiucani, Chișinău mun.
# m2
# 179 000 €
# 18 iul. 2025, 14:38
# Apartament cu 1 cameră, Râșcani, Chișinău, Chișinău mun.
# m2
# 73 000 €
# 18 iul. 2025, 14:38
# Apartament cu 3 camere, Râșcani, Chișinău, Chișinău mun.
# m2
# 300 000 €
# 18 iul. 2025, 14:38
# Apartament cu 2 camere, Durlești, Chișinău, Chișinău mun.
# m2
# 79 860 €
# 18 iul. 2025, 14:38
# Apartament cu 2 camere, Centru, Chișinău, Chișinău mun.
# m2
# 145 000 €
# 18 iul. 2025, 14:38
# Apartament cu 2 camere, Durlești, Chișinău, Chișinău mun.
# m2
# 60 895 €
# 18 iul. 2025, 14:38
# Apartament cu 1 cameră, Buiucani, Chișinău, Chișinău mun.
# m2
# 55 080 €
# 18 iul. 2025, 14:38

# %%
user_price = '75 000'
for ad in ads:
    if user_price in ad.text:
        print(ad.text)
# Out:
# Apartament cu 3 camere, Ciocana, Chișinău, Chișinău mun.
# m2
# 75 000 €
# 18 iul. 2025, 15:15
# Apartament cu 1 cameră, Durlești, Chișinău, Chișinău mun.
# m2
# 75 000 €
# 18 iul. 2025, 15:15

# %%
data = {}
adid = 0
for ad in ads:
    adlink = ad.find_element(By.CSS_SELECTOR, "a.AdShort_title__link__EnVP9").get_attribute("href") 
    adData = adlink
    data.update({adid : adData})
    adid = adid + 1
print(len(data))
data
# Out:
# 84
# {0: 'https://999.md/ro/101632453',
#  1: 'https://999.md/ro/89639002',
#  2: 'https://999.md/ro/88326179',
#  3: 'https://999.md/ro/83035889',
#  4: 'https://999.md/ro/101253833',
#  5: 'https://999.md/ro/100001542',
#  6: 'https://999.md/ro/100730878',
#  7: 'https://999.md/ro/100369423',
#  8: 'https://999.md/ro/101022855',
#  9: 'https://999.md/ro/101302578',
#  10: 'https://999.md/ro/101060287',
#  11: 'https://999.md/ro/100735061?clickToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..L_cTo2OR7ne3W3ciwg385ds2WCjPHTgoE0aEyMrOM9I&adType=booster',
#  12: 'https://999.md/ro/101262874',
#  13: 'https://999.md/ro/101219388',
#  14: 'https://999.md/ro/100607795',
#  15: 'https://999.md/ro/101603877',
#  16: 'https://999.md/ro/101611643',
#  17: 'https://999.md/ro/101220776',
#  18: 'https://999.md/ro/101632444',
#  19: 'https://999.md/ro/101318249',
#  20: 'https://999.md/ro/101404030',
#  21: 'https://999.md/ro/101457428',
#  22: 'https://999.md/ro/87511943?clickToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..ETWkR2B9BghEmwWffxGRGVBcz8wR86_PIS8FtTnGLDI&adType=booster',
#  23: 'https://999.md/ro/101632419',
#  24: 'https://999.md/ro/101596222',
#  25: 'https://999.md/ro/101632416',
#  26: 'https://999.md/ro/101621354',
#  27: 'https://999.md/ro/101110124',
#  28: 'https://999.md/ro/101014157',
#  29: 'https://999.md/ro/100601668',
#  30: 'https://999.md/ro/101471605',
#  31: 'https://999.md/ro/100628315',
#  32: 'https://999.md/ro/100833238',
#  33: 'https://999.md/ro/101079977',
#  34: 'https://999.md/ro/100370129',
#  35: 'https://999.md/ro/101564430?clickToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..k_MoLlWkyp1DBWa6seedm-U9RvOeYexNogKk3gNKr8k&adType=booster',
#  36: 'https://999.md/ro/101365453',
#  37: 'https://999.md/ro/101211939',
#  38: 'https://999.md/ro/100653351',
#  39: 'https://999.md/ro/101014076',
#  40: 'https://999.md/ro/101214317',
#  41: 'https://999.md/ro/88599945',
#  42: 'https://999.md/ro/100040456',
#  43: 'https://999.md/ro/101526573',
#  44: 'https://999.md/ro/101632389',
#  45: 'https://999.md/ro/101536254?clickToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..UsT3P1PmvzYgyeWsR2pcSueLYIw7poSOS_a8urVrU7E&adType=booster',
#  46: 'https://999.md/ro/101632382',
#  47: 'https://999.md/ro/101632378',
#  48: 'https://999.md/ro/88608168',
#  49: 'https://999.md/ro/100837771',
#  50: 'https://999.md/ro/101621674',
#  51: 'https://999.md/ro/100249472',
#  52: 'https://999.md/ro/100689318',
#  53: 'https://999.md/ro/101518368',
#  54: 'https://999.md/ro/101131927',
#  55: 'https://999.md/ro/89760365',
#  56: 'https://999.md/ro/101016545',
#  57: 'https://999.md/ro/101589352',
#  58: 'https://999.md/ro/89760518',
#  59: 'https://999.md/ro/78717461?clickToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..yFneMyIA2LxbHGY7zkFAhItPYQ5tgaFYNFCDhXBZZX0&adType=booster',
#  60: 'https://999.md/ro/89863994',
#  61: 'https://999.md/ro/101581862',
#  62: 'https://999.md/ro/100776693',
#  63: 'https://999.md/ro/100860843',
#  64: 'https://999.md/ro/101364546',
#  65: 'https://999.md/ro/89777186',
#  66: 'https://999.md/ro/89697488',
#  67: 'https://999.md/ro/101153242',
#  68: 'https://999.md/ro/101614851',
#  69: 'https://999.md/ro/101446443',
#  70: 'https://999.md/ro/100743068?clickToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..WbgaYU57sW1Fuh2q76Mt8FzPyeB3VpNQv3QUcWJ1g-8&adType=booster',
#  71: 'https://999.md/ro/101626286',
#  72: 'https://999.md/ro/101162985',
#  73: 'https://999.md/ro/101343163',
#  74: 'https://999.md/ro/88738934',
#  75: 'https://999.md/ro/101492355',
#  76: 'https://999.md/ro/100293238',
#  77: 'https://999.md/ro/101403870',
#  78: 'https://999.md/ro/101632349',
#  79: 'https://999.md/ro/88738796',
#  80: 'https://999.md/ro/101204474',
#  81: 'https://999.md/ro/100359196',
#  82: 'https://999.md/ro/100369740',
#  83: 'https://999.md/ro/100589011'}

# %%
with open("links.csv", mode="w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(['links'])

    for link in data.values():
        writer.writerow([link])

# %%
df = pd.read_csv('links.csv')
df
# Out:
#                           links
# 0   https://999.md/ro/101632453
# 1    https://999.md/ro/89639002
# 2    https://999.md/ro/88326179
# 3    https://999.md/ro/83035889
# 4   https://999.md/ro/101253833
# ..                          ...
# 79   https://999.md/ro/88738796
# 80  https://999.md/ro/101204474
# 81  https://999.md/ro/100359196
# 82  https://999.md/ro/100369740
# 83  https://999.md/ro/100589011
#
# [84 rows x 1 columns]

# %%
button_next = browser.find_element(By.CLASS_NAME,'Pagination_pagination__container__buttons__wrapper__icon__next__A22Rc')
button_next.click()
print(browser.current_url)
# Out:
# https://999.md/ro/list/real-estate/apartments-and-rooms?view_type=short&appl=1&ef=16%2C6%2C2307%2C2200&eo=13859%2C12885%2C12900%2C12912&o_16_1=776&o_32_8_12900=13859&page=2

# %%
button_back = browser.find_element(By.CLASS_NAME,'Pagination_pagination__container__buttons__wrapper__icon__previous__njSYV')
button_back.click()

# %%
def pageLinksExtractor(link):
    global browser
    page = browser.current_url
    adsblock = browser.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div/div[2]')
    adlist = adsblock.find_elements(By.CLASS_NAME,'AdShort_wrapper__S8kqq')
    data = {}
    adid = 0
    for ad in ads:
        adlink = ad.find_element(By.CSS_SELECTOR, "a.AdShort_title__link__EnVP9").get_attribute("href") 
        adData = adlink
        data.update({adid : adData})
        adid = adid + 1
        
    
    if 'page=' in page:
        index = page[-1]
    else:
        index = '1'
    file_path = f"links pages/page{index}.csv"

    with open(file_path, mode="w", encoding="utf-8", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(['links'])

        for link in data.values():
            writer.writerow([link])

# %%
page = browser.current_url
print(page)
pageLinksExtractor(page)
# Out:
# https://999.md/ro/list/real-estate/apartments-and-rooms?view_type=short&appl=1&ef=16%2C6%2C2307%2C2200&eo=13859%2C12885%2C12900%2C12912&o_16_1=776&o_32_8_12900=13859

# %%
setpage = 'https://999.md/ro/list/real-estate/apartments-and-rooms?view_type=short&appl=1&ef=16%2C6%2C2307%2C2200&eo=13859%2C12885%2C12900%2C12912&o_16_1=776&o_32_8_12900=13859'

# %%
lastpage = browser.find_element(By.CLASS_NAME,'Pagination_pagination__container__buttons__wrapper__icon__last__page__84ROu')
lastpage.click()
print(browser.current_url)
#browser.find_element(By.CLASS_NAME,'Pagination_pagination__container__buttons__wrapper__button__PeVvM Pagination_active__BzFMR').text

# %%
url = 'https://999.md/ro/list/real-estate/apartments-and-rooms?view_type=short&appl=1&ef=16%2C6%2C2307%2C2200&eo=13859%2C12885%2C12900%2C12912&o_16_1=776&o_32_8_12900=13859&page=217'
pagenumberindex = url.index('page=') 
print(url[pagenumberindex:].replace('page=',''))

# %%
browser.quit()
